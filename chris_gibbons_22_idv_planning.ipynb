# %% [markdown]
# This is the file that will be submitted for the Project Planning Stage (Individual) assignment in Canvas.

# %% [markdown]
# ## GitHub Repository

# %% [markdown]
# Link to GitHub repository for planning stage: https://github.com/chrispy-tacos/dsci_idv_planning.git
